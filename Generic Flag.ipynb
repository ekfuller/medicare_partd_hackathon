# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('./data/medicare_partd_20162020_filled.csv')

# %%
df[df['Mftr_Name']=='Overall']
# Out:
#                             Brnd_Name                       Gnrc_Name  \
# 0            1st Tier Unifine Pentips            Pen Needle, Diabetic
# 2       1st Tier Unifine Pentips Plus            Pen Needle, Diabetic
# 4                            Abacavir                Abacavir Sulfate
# 13                Abacavir-Lamivudine     Abacavir Sulfate/Lamivudine
# 20     Abacavir-Lamivudine-Zidovudine  Abacavir/Lamivudine/Zidovudine
# ...                               ...                             ...
# 13557                   Zyprexa Zydis                      Olanzapine
# 13559                        Zyprexa*                      Olanzapine
# 13561                          Zytiga             Abiraterone Acetate
# 13564                           Zyvox                       Linezolid
# 13566                           Zyvox        Linezolid In Dextrose 5%
#
#        Tot_Mftr Mftr_Name  Tot_Spndng_2016  Tot_Dsg_Unts_2016  Tot_Clms_2016  \
# ...

# %%
df[df['Gnrc_Name']=='Pen Needle, Diabetic']
# Out:
#                            Brnd_Name             Gnrc_Name  Tot_Mftr  \
# 0           1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 1           1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 2      1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 3      1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 264              Advocate Pen Needle  Pen Needle, Diabetic         1
# ...                              ...                   ...       ...
# 12670           Unifine Pentips Plus  Pen Needle, Diabetic         1
# 12671           Unifine Pentips Plus  Pen Needle, Diabetic         1
# 12672           Unifine Pentips Plus  Pen Needle, Diabetic         1
# 12673           Unifine Pentips Plus  Pen Needle, Diabetic         1
# 12674           Unifine Pentips Plus  Pen Needle, Diabetic         1
#
#              Mftr_Name  Tot_Spndng_2016  Tot_Dsg_Unts_2016  Tot_Clms_2016  \
# ...

# %%
df[df['Brnd_Name']=='Advocate Syringes']
# Out:
#              Brnd_Name                       Gnrc_Name  Tot_Mftr  \
# 268  Advocate Syringes  Syring-Needl,Disp,Insul,0.3 Ml         1
# 269  Advocate Syringes  Syring-Needl,Disp,Insul,0.3 Ml         1
# 270  Advocate Syringes  Syringe And Needle,Insulin,1ml         1
# 271  Advocate Syringes  Syringe And Needle,Insulin,1ml         1
# 272  Advocate Syringes   Syringe-Needle,Insulin,0.5 Ml         1
# 273  Advocate Syringes   Syringe-Needle,Insulin,0.5 Ml         1
#
#            Mftr_Name  Tot_Spndng_2016  Tot_Dsg_Unts_2016  Tot_Clms_2016  \
# 268          Overall         58159.52           128184.0         1469.0
# 269  Diabetic Supply         58159.52           128184.0         1469.0
# 270          Overall        142271.90           308281.0         3213.0
# 271  Diabetic Supply        142271.90           308281.0         3213.0
# 272          Overall        137847.29           303950.0         3442.0
# 273  Diabetic Supply        137847.29           303950.0         3442.0
#
# ...

# %%
df[(df['Tot_Mftr']==1) & (df['Mftr_Name']=='Overall')]
# Out:
#                             Brnd_Name                       Gnrc_Name  \
# 0            1st Tier Unifine Pentips            Pen Needle, Diabetic
# 2       1st Tier Unifine Pentips Plus            Pen Needle, Diabetic
# 20     Abacavir-Lamivudine-Zidovudine  Abacavir/Lamivudine/Zidovudine
# 22                            Abelcet    Amphotericin B Lipid Complex
# 24                   Abilify Maintena                    Aripiprazole
# ...                               ...                             ...
# 13553                       Zypitamag          Pitavastatin Magnesium
# 13555                Zyprexa Relprevv              Olanzapine Pamoate
# 13557                   Zyprexa Zydis                      Olanzapine
# 13559                        Zyprexa*                      Olanzapine
# 13564                           Zyvox                       Linezolid
#
#        Tot_Mftr Mftr_Name  Tot_Spndng_2016  Tot_Dsg_Unts_2016  Tot_Clms_2016  \
# ...

# %%
brand_names = list(df[(df['Tot_Mftr']==1) & (df['Mftr_Name']=='Overall')]['Brnd_Name'])

# %%
len(brand_names)
# Out:
# 2520

# %%
df['generic']= np.where((df['Tot_Mftr']==1) &(df['Mftr_Name']=='Overall'),0,1) 1 in

# %%
df['generic'].value_counts()
# Out:
# 1    11050
# 0     2520
# Name: generic, dtype: int64
